# %%
import os
dataset_path=r"C:\Users\DELL\Downloads\birds_species"
categories=os.listdir(dataset_path)
print(categories)
# Out:
# ['ABBOTTS BABBLER', 'ABBOTTS BOOBY', 'ABYSSINIAN GROUND HORNBILL', 'AFRICAN CROWNED CRANE', 'AFRICAN EMERALD CUCKOO', 'AFRICAN OYSTER CATCHER', 'AFRICAN PIED HORNBILL', 'AFRICAN PYGMY GOOSE', 'ALBATROSS', 'ALBERTS TOWHEE', 'ALPINE CHOUGH', 'ALTAMIRA YELLOWTHROAT', 'AMERICAN AVOCET', 'AMERICAN BITTERN', 'AMERICAN COOT', 'AMERICAN DIPPER', 'AMERICAN FLAMINGO', 'AMERICAN GOLDFINCH', 'AMERICAN PIPIT', 'AMERICAN REDSTART', 'AMERICAN ROBIN', 'AMERICAN WIGEON', 'AMETHYST WOODSTAR', 'ANDEAN GOOSE', 'ANDEAN LAPWING', 'ANHINGA', 'ANIANIAU', 'ANNAS HUMMINGBIRD', 'APAPANE', 'APOSTLEBIRD', 'ARARIPE MANAKIN', 'ASHY STORM PETREL', 'ASHY THRUSHBIRD', 'ASIAN CRESTED IBIS', 'ASIAN DOLLARD BIRD', 'ASIAN GREEN BEE EATER', 'ASIAN OPENBILL STORK', 'AUCKLAND SHAQ', 'AUSTRALASIAN FIGBIRD', 'AVADAVAT', 'AZARAS SPINETAIL', 'AZURE JAY', 'AZURE TANAGER', 'AZURE TIT', 'BAIKAL TEAL', 'BALD EAGLE', 'BALD IBIS', 'BANANAQUIT', 'BAND TAILED GUAN', 'BANDED BROADBILL', 'BANDED PITA', 'BANDED STILT', 'BAR-TAILED GODWIT', 'BARN OWL', 'BARN SWALLOW', 'BEARDED BARBET', 'BEARDED BELLBIRD', 'BEARDED REEDLING', 'BELTED KINGFISHER', 'BIRD OF PARADISE', 'BLACK AND YELLOW BROADBILL', 'BLACK BAZA', 'BLACK BREASTED PUFFBIRD', 'BLACK COCKATO', 'BLACK FACED SPOONBILL', 'BLACK FRANCOLIN', 'BLACK NECKED STILT', 'BLACK SKIMMER', 'BLACK SWAN', 'BLACK TAIL CRAKE', 'BLACK THROATED BUSHTIT', 'BLACK THROATED HUET', 'BLACK THROATED WARBLER', 'BLACK VENTED SHEARWATER', 'BLACK VULTURE', 'BLACK-CAPPED CHICKADEE', 'BLACK-NECKED GREBE', 'BLACK-THROATED SPARROW', 'BLACKBURNIAM WARBLER', 'BLONDE CRESTED WOODPECKER', 'BLOOD PHEASANT', 'BLUE DACNIS', 'BLUE GRAY GNATCATCHER', 'BLUE GROSBEAK', 'BLUE HERON', 'BLUE MALKOHA', 'BLUE THROATED TOUCANET', 'BOBOLINK', 'BORNEAN LEAFBIRD', 'BORNEAN PHEASANT', 'BREWERS BLACKBIRD', 'BROWN HEADED COWBIRD', 'BROWN NOODY', 'BUFFLEHEAD', 'BULWERS PHEASANT', 'BURCHELLS COURSER', 'BUSH TURKEY', 'CAATINGA CACHOLOTE', 'CABOTS TRAGOPAN', 'CALIFORNIA CONDOR', 'CALIFORNIA GULL', 'CAMPO FLICKER', 'CANARY', 'CANVASBACK', 'CAPE GLOSSY STARLING', 'CAPE LONGCLAW', 'CAPE MAY WARBLER', 'CAPE ROCK THRUSH', 'CAPPED HERON', 'CAPUCHINBIRD', 'CASPIAN TERN', 'CEDAR WAXWING', 'CERULEAN WARBLER', 'CHARA DE COLLAR', 'CHATTERING LORY', 'CHESTNUT WINGED CUCKOO', 'CHINESE BAMBOO PARTRIDGE', 'CHINESE POND HERON', 'CHIPPING SPARROW', 'CHUCAO TAPACULO', 'CINNAMON FLYCATCHER', 'CINNAMON TEAL', 'CLARKS GREBE', 'CLARKS NUTCRACKER', 'COCK OF THE  ROCK', 'COLLARED ARACARI', 'COLLARED CRESCENTCHEST', 'COMMON FIRECREST', 'COMMON GRACKLE', 'COMMON HOUSE MARTIN', 'COMMON IORA', 'COMMON LOON', 'COMMON POORWILL', 'COPPERY TAILED COUCAL', 'CRAB PLOVER', 'CRANE HAWK', 'CREAM COLORED WOODPECKER', 'CRESTED AUKLET', 'CRESTED COUA', 'CRESTED FIREBACK', 'CRESTED KINGFISHER', 'CRESTED OROPENDOLA', 'CRESTED SERPENT EAGLE', 'CRESTED SHRIKETIT', 'CRIMSON CHAT', 'CROW', 'CUBAN TODY', 'CUBAN TROGON', 'DALMATIAN PELICAN', 'DARJEELING WOODPECKER', 'DARK EYED JUNCO', 'DAURIAN REDSTART', 'DEMOISELLE CRANE', 'DOUBLE BARRED FINCH', 'DOUBLE EYED FIG PARROT', 'DOWNY WOODPECKER', 'DUNLIN', 'DUSKY LORY', 'DUSKY ROBIN', 'EARED PITA', 'EASTERN BLUEBIRD', 'EASTERN BLUEBONNET', 'EASTERN MEADOWLARK', 'EASTERN ROSELLA', 'EASTERN TOWEE', 'EASTERN WIP POOR WILL', 'EASTERN YELLOW ROBIN', 'ECUADORIAN HILLSTAR', 'EGYPTIAN GOOSE', 'ELEGANT TROGON', 'ELLIOTS  PHEASANT', 'EMERALD TANAGER', 'EMPEROR PENGUIN', 'ENGGANO MYNA', 'EURASIAN BULLFINCH', 'EURASIAN GOLDEN ORIOLE', 'EURASIAN MAGPIE', 'EUROPEAN GOLDFINCH', 'FAIRY BLUEBIRD', 'FAIRY PENGUIN', 'FAIRY TERN', 'FAN TAILED WIDOW', 'FIERY MINIVET', 'FIORDLAND PENGUIN', 'FIRE TAILLED MYZORNIS', 'FLAME BOWERBIRD', 'FOREST WAGTAIL', 'FRIGATE', 'FRILL BACK PIGEON', 'GANG GANG COCKATOO', 'GILA WOODPECKER', 'GILDED FLICKER', 'GLOSSY IBIS', 'GO AWAY BIRD', 'GOLD WING WARBLER', 'GOLDEN BOWER BIRD', 'GOLDEN CHEEKED WARBLER', 'GOLDEN EAGLE', 'GOLDEN PARAKEET', 'GOLDEN PHEASANT', 'GOULDIAN FINCH', 'GRANDALA', 'GRAY CATBIRD', 'GRAY KINGBIRD', 'GRAY PARTRIDGE', 'GREAT GRAY OWL', 'GREAT JACAMAR', 'GREAT ...

# %%
img_path=[]
labels=[]
for category in categories:
    folder_path=os.path.join(dataset_path,category)
    for file in os.listdir(folder_path):
        file_path=os.path.join(folder_path,file)
        img_path.append(file_path)
        labels.append(category)

# %%
img_path[:5]
# Out:
# ['C:\\Users\\DELL\\Downloads\\birds_species\\ABBOTTS BABBLER\\1.jpg',
#  'C:\\Users\\DELL\\Downloads\\birds_species\\ABBOTTS BABBLER\\2.jpg',
#  'C:\\Users\\DELL\\Downloads\\birds_species\\ABBOTTS BABBLER\\3.jpg',
#  'C:\\Users\\DELL\\Downloads\\birds_species\\ABBOTTS BABBLER\\4.jpg',
#  'C:\\Users\\DELL\\Downloads\\birds_species\\ABBOTTS BABBLER\\5.jpg']

# %%
labels[:5]
# Out:
# ['ABBOTTS BABBLER',
#  'ABBOTTS BABBLER',
#  'ABBOTTS BABBLER',
#  'ABBOTTS BABBLER',
#  'ABBOTTS BABBLER']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(img_path,labels,test_size=0.2,random_state=42)

# %%
list(enumerate(categories))
# Out:
# [(0, 'ABBOTTS BABBLER'),
#  (1, 'ABBOTTS BOOBY'),
#  (2, 'ABYSSINIAN GROUND HORNBILL'),
#  (3, 'AFRICAN CROWNED CRANE'),
#  (4, 'AFRICAN EMERALD CUCKOO'),
#  (5, 'AFRICAN OYSTER CATCHER'),
#  (6, 'AFRICAN PIED HORNBILL'),
#  (7, 'AFRICAN PYGMY GOOSE'),
#  (8, 'ALBATROSS'),
#  (9, 'ALBERTS TOWHEE'),
#  (10, 'ALPINE CHOUGH'),
#  (11, 'ALTAMIRA YELLOWTHROAT'),
#  (12, 'AMERICAN AVOCET'),
#  (13, 'AMERICAN BITTERN'),
#  (14, 'AMERICAN COOT'),
#  (15, 'AMERICAN DIPPER'),
#  (16, 'AMERICAN FLAMINGO'),
#  (17, 'AMERICAN GOLDFINCH'),
#  (18, 'AMERICAN PIPIT'),
#  (19, 'AMERICAN REDSTART'),
#  (20, 'AMERICAN ROBIN'),
#  (21, 'AMERICAN WIGEON'),
#  (22, 'AMETHYST WOODSTAR'),
#  (23, 'ANDEAN GOOSE'),
#  (24, 'ANDEAN LAPWING'),
#  (25, 'ANHINGA'),
#  (26, 'ANIANIAU'),
#  (27, 'ANNAS HUMMINGBIRD'),
#  (28, 'APAPANE'),
#  (29, 'APOSTLEBIRD'),
#  (30, 'ARARIPE MANAKIN'),
#  (31, 'ASHY STORM PETREL'),
#  (32, 'ASHY THRUSHBIRD'),
#  (33, 'ASIAN CRESTED IBIS'),
#  (34, 'ASIAN DOLLARD BIRD'),
#  (35, 'ASIAN GREEN BEE EATER'),
#  (36, 'ASIAN OPENBILL STORK'),
#  (37, 'AUCKLAND SHAQ'),
#  (38, 'AUSTRALASIAN FIGBIRD'),
#  (39, 'AVADAVAT'),
#  (40, 'AZARAS SPINETAIL'),
#  (41, 'AZURE JAY'),
#  (42, 'AZURE TANAGER'),
#  (43, 'AZURE TIT'),
#  (44, 'BAIKAL TEAL'),
#  (45, 'BALD EAGLE'),
#  (46, 'BALD IBIS'),
#  (47, 'BANANAQUIT'),
#  (48, 'BAND TAILED GUAN'),
#  (49, 'BANDED BROADBILL'),
#  (50, 'BANDED PITA'),
#  (51, 'BANDED STILT'),
#  (52, 'BAR-TAILED GODWIT'),
#  (53, 'BARN OWL'),
#  (54, 'BARN SWALLOW'),
#  (55, 'BEARDED BARBET'),
#  (56, 'BEARDED BELLBIRD'),
#  (57, 'BEARDED REEDLING'),
#  (58, 'BELTED KINGFISHER'),
#  (59, 'BIRD OF PARADISE'),
#  (60, 'BLACK AND YELLOW BROADBILL'),
#  (61, 'BLACK BAZA'),
#  (62, 'BLACK BREASTED PUFFBIRD'),
#  (63, 'BLACK COCKATO'),
#  (64, 'BLACK FACED SPOONBILL'),
#  (65, 'BLACK FRANCOLIN'),
#  (66, 'BLACK NECKED STILT'),
#  (67, 'BLACK SKIMMER'),
#  (68, 'BLACK SWAN'),
#  (69, 'BLACK TAIL CRAKE'),
#  (70, 'BLACK THROATED BUSHTIT'),
#  (71, 'BLACK THROATED HUET'),
#  (72, 'BLACK THROATED WARBLER'),
#  (73, 'BLACK VENTED SHEARWATER'),
#  (74, 'BLACK VULTURE'),
#  (75, 'BLACK-CAPPED CHICKADEE'),
#  (76, 'BLACK-NECKED GREBE'),
#  (77, 'BLACK-THROATED SPARROW'),
#  (78, 'BLACKBURNIAM WARBLER'),
#  (79, 'BLONDE CRESTED WOODPECKER'),
#  (80, 'BLOOD PHEASANT'),
#  (81, 'BLUE DACNIS'),
#  (82, 'BLUE GRAY GNATCATCHER'),
#  (83, 'BLUE GROSBEAK'),
#  (84, 'BLUE HERON'),
#  (85, 'BLUE MALKOHA'),
#  (86, 'BLUE THROATED TOUCANET'),
#  (87, 'BOBOLINK'),
#  (88, 'BORNEAN LEAFBIRD'),
#  (89, 'BORNEAN PHEASANT'),
#  (90, 'BREWERS BLACKBIRD'),
#  (91, 'BROWN HEADED COWBIRD'),
#  (92, 'BROWN NOODY'),
#  (93, 'BUFFLEHEAD'),
#  (94, 'BULWERS PHEASANT'),
#  (95, 'BURCHELLS COURSER'),
#  (96, 'BUSH TURKEY'),
#  (97, 'CAATINGA CACHOLOTE'),
#  (98, 'CABOTS TRAGOPAN'),
#  (99, 'CALIFORNIA CONDOR'),
#  (100, 'CALIFORNIA GULL'),
#  (101, 'CAMPO FLICKER'),
#  (102, 'CANARY'),
#  (103, 'CANVASBACK'),
#  (104, 'CAPE GLOSSY STARLING'),
#  (105, 'CAPE LONGCLAW'),
#  (106, 'CAPE MAY WARBLER'),
#  (107, 'CAPE ROCK THRUSH'),
#  (108, 'CAPPED HERON'),
#  (109, 'CAPUCHINBIRD'),
#  (110, 'CASPIAN TERN'),
#  (111, 'CEDAR WAXWING'),
#  (112, 'CERULEAN WARBLER'),
#  (113, 'CHARA DE COLLAR'),
#  (114, 'CHATTERING LORY'),
#  (115, 'CHESTNUT WINGED CUCKOO'),
#  (116, 'CHINESE BAMBOO PARTRIDGE'),
#  (117, 'CHINESE POND HERON'),
#  (118, 'CHIPPING SPARROW'),
#  (119, 'CHUCAO TAPACULO'),
#  (120, 'CINNAMON FLYCATCHER'),
#  (121, 'CINNAMON TEAL'),
#  (122, 'CLARKS GREBE'),
#  (123, 'CLARKS NUTCRACKER'),
#  (124, 'COCK OF THE  ROCK'),
#  (125, 'COLLARED ARACARI'),
#  (126, 'COLLARED CRESCENTCHEST'),
#  (127, 'COMMON FIRECREST'),
#  (128, 'COMMON GRACKLE'),
#  (129, 'COMMON HOUSE MARTIN'),
#  (130, 'COMMON IORA'),
#  (131, 'COMMON LOON'),
#  (132, 'COMMON POORWILL'),
#  (133, 'COPPERY TAILED COUCAL'),
#  (134, 'CRAB PLOVER'),
#  (135, 'CRANE HAWK'),
#  (136, 'CREAM COLORED WOODPECKER'),
#  (137, 'CRESTED AUKLET'),
#  (138, 'CRESTED COUA'),
#  (139, 'CRESTED FIREBACK'),
#  (140, 'CRESTED KINGFISHER'),
#  (141, 'CRESTED OROPENDOLA'),
#  (142, 'CRESTED SERPENT EAGLE'),
#  (143, 'CRESTED SHRIKETIT'),
#  (144, 'CRIMSON CHAT'),
#  (145, 'CROW'),
#  (146, 'CUBAN TODY'),
#  (147, 'CUBAN TROGON'),
#  (148, 'DALMATIAN PELICAN'),
#  (149, 'DARJEELING WOODPECKER'),
#  (150, 'DARK EYED JUNCO'),
#  (151, 'DAURIAN REDSTART'),
#  (152, 'DEMOISELLE CRANE'),
#  (153, 'DOUBLE BARRED FINCH'),
#  (154, 'DOUBLE EYED FIG PARROT'),
#  (155, 'DOWNY WOODPECKER'),
#  (156, 'DUNLIN'),
#  (157, 'DUSKY LORY'),
#  (158, 'DUSKY ROBIN'),
#  (159, 'EARED PITA'),
#  (160, 'EASTERN BLUEBIRD'),
#  (161, 'EASTERN BLUEBONNET'),
#  (162, 'EASTERN MEADOWLARK'),
#  (163, 'EASTERN ROSELLA'),
#  (164, 'EASTERN TOWEE'),
#  (165, 'EASTERN WIP POOR WILL'),
#  (166, 'EASTERN YELLOW ROBIN'),
#  (167, 'ECUADORIAN HILLSTAR'),
#  (168, 'EGYPTIAN GOOSE'),
#  (169, 'ELEGANT TROGON'),
#  (170, 'ELLIOTS  PHEASANT'),
#  (171, 'EMERALD TANAGER'),
#  (172, 'EMPEROR PENGUIN'),
#  (173, 'ENGGANO MYNA'),
#  (174, 'EURASIAN BULLFINCH'),
#  (175, 'EURASIAN GOLDEN ORIOLE'),
#  (176, 'EURASIAN MAGPIE'),
#  (177, 'EUROPEAN GOLDFINCH'),
#  (178, 'FAIRY BLUEBIRD'),
#  (179, 'FAIRY PENGUIN'),
#  (180, 'FAIRY TERN'),
#  (181, 'FAN TAILED WIDOW'),
#  (182, 'FIERY MINIVET'),
#  (183, 'FIORDLAND PENGUIN'),
#  (184, 'FIRE TAILLED MYZORNIS'),
#  (185, 'FLAME BOWERBIRD'),
#  (186, 'FOREST WAGTAIL'),
#  (187, 'FRIGATE'),
#  (188, 'FRILL BACK PIGEON'),
#  (189, 'GANG GANG COCKATOO'),
#  (190, 'GILA WOODPECKER'),
#  (191, 'GILDED FLICKER'),
#  (192, 'GLOSSY IBIS'),
#  (193, 'GO AWAY BIRD'),
#  (194, 'GOLD WING WARBLER'),
#  (195, 'GOLDEN BOWER BIRD'),
#  (196, 'GOLDEN CHEEKED WARBLER'),
#  (197, 'GOLDEN EAGLE'),
#  (198, 'GOLDEN PARAKEET'),
#  (199, 'GOLDEN PHEASANT'),
#  (200, 'GOULDIAN FINCH'),
#  (201, 'GRANDALA'),
#  (202, 'GRAY CATBIRD'),
#  (203, 'GRAY KINGBIRD'),
#  (204, 'GRAY PARTRIDGE'),
#  (205, 'GREAT GRAY OWL'),
#  (206, 'GREAT JACAMAR'),
#  (207, 'GREAT KISKADEE'),
#  (208, 'GREAT POTOO'),
#  (209, 'GREAT TINAMOU'),
#  (210, 'GREAT XENOPS'),
#  (211, 'GREATER PEWEE'),
#  (212, 'GREATER PRAIRIE CHICKEN'),
#  (213, 'GREATOR SAGE GROUSE'),
#  (214, 'GREEN JAY'),
#  (215, 'GREEN MAGPIE'),
#  (216, 'GREEN WINGED DOVE'),
#  (217, 'GREY CUCKOOSHRIKE'),
#  (218, 'GREY HEADED CHACHALACA'),
#  (219, 'GREY HEADED FISH EAGLE'),
#  (220, 'GREY PLOVER'),
#  (221, 'GROVED BILLED ANI'),
#  (222, 'GUINEA TURACO'),
#  (223, 'GUINEAFOWL'),
#  (224, 'GURNEYS PITTA'),
#  (225, 'GYRFALCON'),
#  (226, 'HAMERKOP'),
#  (227, 'HARLEQUIN DUCK'),
#  (228, 'HARLEQUIN QUAIL'),
#  (229, 'HARPY EAGLE'),
#  (230, 'HAWAIIAN GOOSE'),
#  (231, 'HAWFINCH'),
#  (232, 'HELMET VANGA'),
#  (233, 'HEPATIC TANAGER'),
#  (234, 'HIMALAYAN BLUETAIL'),
#  (235, 'HIMALAYAN MONAL'),
#  (236, 'HOATZIN'),
#  (237, 'HOOPOES'),
#  (238, 'HORNED GUAN'),
#  (239, 'HORNED LARK'),
#  (240, 'HORNED SUNGEM'),
#  (241, 'HOUSE FINCH'),
#  (242, 'HOUSE SPARROW'),
#  (243, 'HYACINTH MACAW'),
#  (244, 'IBERIAN MAGPIE'),
#  (245, 'IBISBILL'),
#  (246, 'IMPERIAL SHAQ'),
#  (247, 'INCA TERN'),
#  (248, 'INDIAN BUSTARD'),
#  (249, 'INDIAN PITTA'),
#  (250, 'INDIAN ROLLER'),
#  (251, 'INDIAN VULTURE'),
#  (252, 'INDIGO BUNTING'),
#  (253, 'INDIGO FLYCATCHER'),
#  (254, 'INLAND DOTTEREL'),
#  (255, 'IVORY BILLED ARACARI'),
#  (256, 'IVORY GULL'),
#  (257, 'IWI'),
#  (258, 'JABIRU'),
#  (259, 'JACK SNIPE'),
#  (260, 'JACOBIN PIGEON'),
#  (261, 'JANDAYA PARAKEET'),
#  (262, 'JAPANESE ROBIN'),
#  (263, 'JAVA SPARROW'),
#  (264, 'JOCOTOCO ANTPITTA'),
#  (265, 'KAGU'),
#  (266, 'KAKAPO'),
#  (267, 'KILLDEAR'),
#  (268, 'KING EIDER'),
#  (269, 'KING VULTURE'),
#  (270, 'KIWI'),
#  (271, 'KNOB BILLED DUCK'),
#  (272, 'KOOKABURRA'),
#  (273, 'LAUGHING GULL'),
#  (274, 'LAZULI BUNTING'),
#  (275, 'LESSER ADJUTANT'),
#  (276, 'LILAC ROLLER'),
#  (277, 'LIMPKIN'),
#  (278, 'LITTLE AUK'),
#  (279, 'LOGGERHEAD SHRIKE'),
#  (280, 'LONG-EARED OWL'),
#  (281, 'LOONEY BIRDS'),
#  (282, 'LUCIFER HUMMINGBIRD'),
#  (283, 'MAGPIE GOOSE'),
#  (284, 'MALABAR HORNBILL'),
#  (285, 'MALACHITE KINGFISHER'),
#  (286, 'MALAGASY WHITE EYE'),
#  (287, 'MALEO'),
#  (288, 'MALLARD DUCK'),
#  (289, 'MANDRIN DUCK'),
#  (290, 'MANGROVE CUCKOO'),
#  (291, 'MARABOU STORK'),
#  (292, 'MASKED BOBWHITE'),
#  (293, 'MASKED BOOBY'),
#  (294, 'MASKED LAPWING'),
#  (295, 'MCKAYS BUNTING'),
#  (296, 'MERLIN'),
#  (297, 'MIKADO  PHEASANT'),
#  (298, 'MILITARY MACAW'),
#  (299, 'MOURNING DOVE'),
#  (300, 'MYNA'),
#  (301, 'NICOBAR PIGEON'),
#  (302, 'NOISY FRIARBIRD'),
#  (303, 'NORTHERN BEARDLESS TYRANNULET'),
#  (304, 'NORTHERN CARDINAL'),
#  (305, 'NORTHERN FLICKER'),
#  (306, 'NORTHERN FULMAR'),
#  (307, 'NORTHERN GANNET'),
#  (308, 'NORTHERN GOSHAWK'),
#  (309, 'NORTHERN JACANA'),
#  (310, 'NORTHERN MOCKINGBIRD'),
#  (311, 'NORTHERN PARULA'),
#  (312, 'NORTHERN RED BISHOP'),
#  (313, 'NORTHERN SHOVELER'),
#  (314, 'OCELLATED TURKEY'),
#  (315, 'OILBIRD'),
#  (316, 'OKINAWA RAIL'),
#  (317, 'ORANGE BREASTED TROGON'),
#  (318, 'ORANGE BRESTED BUNTING'),
#  (319, 'ORIENTAL BAY OWL'),
#  (320, 'ORNATE HAWK EAGLE'),
#  (321, 'OSPREY'),
#  (322, 'OSTRICH'),
#  (323, 'OVENBIRD'),
#  (324, 'OYSTER CATCHER'),
#  (325, 'PAINTED BUNTING'),
#  (326, 'PALILA'),
#  (327, 'PALM NUT VULTURE'),
#  (328, 'PARADISE TANAGER'),
#  (329, 'PARAKETT AUKLET'),
#  (330, 'PARUS MAJOR'),
#  (331, 'PATAGONIAN SIERRA FINCH'),
#  (332, 'PEACOCK'),
#  (333, 'PEREGRINE FALCON'),
#  (334, 'PHAINOPEPLA'),
#  (335, 'PHILIPPINE EAGLE'),
#  (336, 'PINK ROBIN'),
#  (337, 'PLUSH CRESTED JAY'),
#  (338, 'POMARINE JAEGER'),
#  (339, 'PUFFIN'),
#  (340, 'PUNA TEAL'),
#  (341, 'PURPLE FINCH'),
#  (342, 'PURPLE GALLINULE'),
#  (343, 'PURPLE MARTIN'),
#  (344, 'PURPLE SWAMPHEN'),
#  (345, 'PYGMY KINGFISHER'),
#  (346, 'PYRRHULOXIA'),
#  (347, 'QUETZAL'),
#  (348, 'RAINBOW LORIKEET'),
#  (349, 'RAZORBILL'),
#  (350, 'RED BEARDED BEE EATER'),
#  (351, 'RED BELLIED PITTA'),
#  (352, 'RED BILLED TROPICBIRD'),
#  (353, 'RED BROWED FINCH'),
#  (354, 'RED FACED CORMORANT'),
#  (355, 'RED FACED WARBLER'),
#  (356, 'RED FODY'),
#  (357, 'RED HEADED DUCK'),
#  (358, 'RED HEADED WOODPECKER'),
#  (359, 'RED KNOT'),
#  (360, 'RED LEGGED HONEYCREEPER'),
#  (361, 'RED NAPED TROGON'),
#  (362, 'RED SHOULDERED HAWK'),
#  (363, 'RED TAILED HAWK'),
#  (364, 'RED TAILED THRUSH'),
#  (365, 'RED WINGED BLACKBIRD'),
#  (366, 'RED WISKERED BULBUL'),
#  (367, 'REGENT BOWERBIRD'),
#  (368, 'RING-NECKED PHEASANT'),
#  (369, 'ROADRUNNER'),
#  (370, 'ROCK DOVE'),
#  (371, 'ROSE BREASTED COCKATOO'),
#  (372, 'ROSE BREASTED GROSBEAK'),
#  (373, 'ROSEATE SPOONBILL'),
#  (374, 'ROSY FACED LOVEBIRD'),
#  (375, 'ROUGH LEG BUZZARD'),
#  (376, 'ROYAL FLYCATCHER'),
#  (377, 'RUBY CROWNED KINGLET'),
#  (378, 'RUBY THROATED HUMMINGBIRD'),
#  (379, 'RUDDY SHELDUCK'),
#  (380, 'RUDY KINGFISHER'),
#  (381, 'RUFOUS KINGFISHER'),
#  (382, 'RUFOUS TREPE'),
#  (383, 'RUFUOS MOTMOT'),
#  (384, 'SAMATRAN THRUSH'),
#  (385, 'SAND MARTIN'),
#  (386, 'SANDHILL CRANE'),
#  (387, 'SATYR TRAGOPAN'),
#  (388, 'SAYS PHOEBE'),
#  (389, 'SCARLET CROWNED FRUIT DOVE'),
#  (390, 'SCARLET FACED LIOCICHLA'),
#  (391, 'SCARLET IBIS'),
#  (392, 'SCARLET MACAW'),
#  (393, 'SCARLET TANAGER'),
#  (394, 'SHOEBILL'),
#  (395, 'SHORT BILLED DOWITCHER'),
#  (396, 'SMITHS LONGSPUR'),
#  (397, 'SNOW GOOSE'),
#  (398, 'SNOW PARTRIDGE'),
#  (399, 'SNOWY EGRET'),
#  (400, 'SNOWY OWL'),
#  (401, 'SNOWY PLOVER'),
#  (402, 'SNOWY SHEATHBILL'),
#  (403, 'SORA'),
#  (404, 'SPANGLED COTINGA'),
#  (405, 'SPLENDID WREN'),
#  (406, 'SPOON BILED SANDPIPER'),
#  (407, 'SPOTTED CATBIRD'),
#  (408, 'SPOTTED WHISTLING DUCK'),
#  (409, 'SQUACCO HERON'),
#  (410, 'SRI LANKA BLUE MAGPIE'),
#  (411, 'STEAMER DUCK'),
#  (412, 'STORK BILLED KINGFISHER'),
#  (413, 'STRIATED CARACARA'),
#  (414, 'STRIPED OWL'),
#  (415, 'STRIPPED MANAKIN'),
#  (416, 'STRIPPED SWALLOW'),
#  (417, 'SUNBITTERN'),
#  (418, 'SUPERB STARLING'),
#  (419, 'SURF SCOTER'),
#  (420, 'SWINHOES PHEASANT'),
#  (421, 'TAILORBIRD'),
#  (422, 'TAIWAN MAGPIE'),
#  (423, 'TAKAHE'),
#  (424, 'TASMANIAN HEN'),
#  (425, 'TAWNY FROGMOUTH'),
#  (426, 'TEAL DUCK'),
#  (427, 'TIT MOUSE'),
#  (428, 'TOUCHAN'),
#  (429, 'TOWNSENDS WARBLER'),
#  (430, 'TREE SWALLOW'),
#  (431, 'TRICOLORED BLACKBIRD'),
#  (432, 'TROPICAL KINGBIRD'),
#  (433, 'TRUMPTER SWAN'),
#  (434, 'TURKEY VULTURE'),
#  (435, 'TURQUOISE MOTMOT'),
#  (436, 'UMBRELLA BIRD'),
#  (437, 'VARIED THRUSH'),
#  (438, 'VEERY'),
#  (439, 'VENEZUELIAN TROUPIAL'),
#  (440, 'VERDIN'),
#  (441, 'VERMILION FLYCATHER'),
#  (442, 'VICTORIA CROWNED PIGEON'),
#  (443, 'VIOLET BACKED STARLING'),
#  (444, 'VIOLET CUCKOO'),
#  (445, 'VIOLET GREEN SWALLOW'),
#  (446, 'VIOLET TURACO'),
#  (447, 'VISAYAN HORNBILL'),
#  (448, 'VULTURINE GUINEAFOWL'),
#  (449, 'WALL CREAPER'),
#  (450, 'WATTLED CURASSOW'),
#  (451, 'WATTLED LAPWING'),
#  (452, 'WHIMBREL'),
#  (453, 'WHITE BREASTED WATERHEN'),
#  (454, 'WHITE BROWED CRAKE'),
#  (455, 'WHITE CHEEKED TURACO'),
#  (456, 'WHITE CRESTED HORNBILL'),
#  (457, 'WHITE EARED HUMMINGBIRD'),
#  (458, 'WHITE NECKED RAVEN'),
#  (459, 'WHITE TAILED TROPIC'),
#  (460, 'WILD TURKEY'),
#  (461, 'WILLOW PTARMIGAN'),
#  (462, 'WILSONS BIRD OF PARADISE'),
#  (463, 'WOOD DUCK'),
#  (464, 'WOOD THRUSH'),
#  (465, 'WOODLAND KINGFISHER'),
#  (466, 'YELLOW BELLIED FLOWERPECKER'),
#  (467, 'YELLOW BREASTED CHAT'),
#  (468, 'YELLOW CACIQUE'),
#  (469, 'YELLOW HEADED BLACKBIRD'),
#  (470, 'ZEBRA DOVE')]

# %%
label_map={}

for id,category in enumerate(categories):
    label_map.update({category:id})
print(label_map)
# Out:
# {'ABBOTTS BABBLER': 0, 'ABBOTTS BOOBY': 1, 'ABYSSINIAN GROUND HORNBILL': 2, 'AFRICAN CROWNED CRANE': 3, 'AFRICAN EMERALD CUCKOO': 4, 'AFRICAN OYSTER CATCHER': 5, 'AFRICAN PIED HORNBILL': 6, 'AFRICAN PYGMY GOOSE': 7, 'ALBATROSS': 8, 'ALBERTS TOWHEE': 9, 'ALPINE CHOUGH': 10, 'ALTAMIRA YELLOWTHROAT': 11, 'AMERICAN AVOCET': 12, 'AMERICAN BITTERN': 13, 'AMERICAN COOT': 14, 'AMERICAN DIPPER': 15, 'AMERICAN FLAMINGO': 16, 'AMERICAN GOLDFINCH': 17, 'AMERICAN PIPIT': 18, 'AMERICAN REDSTART': 19, 'AMERICAN ROBIN': 20, 'AMERICAN WIGEON': 21, 'AMETHYST WOODSTAR': 22, 'ANDEAN GOOSE': 23, 'ANDEAN LAPWING': 24, 'ANHINGA': 25, 'ANIANIAU': 26, 'ANNAS HUMMINGBIRD': 27, 'APAPANE': 28, 'APOSTLEBIRD': 29, 'ARARIPE MANAKIN': 30, 'ASHY STORM PETREL': 31, 'ASHY THRUSHBIRD': 32, 'ASIAN CRESTED IBIS': 33, 'ASIAN DOLLARD BIRD': 34, 'ASIAN GREEN BEE EATER': 35, 'ASIAN OPENBILL STORK': 36, 'AUCKLAND SHAQ': 37, 'AUSTRALASIAN FIGBIRD': 38, 'AVADAVAT': 39, 'AZARAS SPINETAIL': 40, 'AZURE JAY': 41, 'AZURE TANAGER': 42, 'AZURE TIT': 43, 'BAIKAL TEAL': 44, 'BALD EAGLE': 45, 'BALD IBIS': 46, 'BANANAQUIT': 47, 'BAND TAILED GUAN': 48, 'BANDED BROADBILL': 49, 'BANDED PITA': 50, 'BANDED STILT': 51, 'BAR-TAILED GODWIT': 52, 'BARN OWL': 53, 'BARN SWALLOW': 54, 'BEARDED BARBET': 55, 'BEARDED BELLBIRD': 56, 'BEARDED REEDLING': 57, 'BELTED KINGFISHER': 58, 'BIRD OF PARADISE': 59, 'BLACK AND YELLOW BROADBILL': 60, 'BLACK BAZA': 61, 'BLACK BREASTED PUFFBIRD': 62, 'BLACK COCKATO': 63, 'BLACK FACED SPOONBILL': 64, 'BLACK FRANCOLIN': 65, 'BLACK NECKED STILT': 66, 'BLACK SKIMMER': 67, 'BLACK SWAN': 68, 'BLACK TAIL CRAKE': 69, 'BLACK THROATED BUSHTIT': 70, 'BLACK THROATED HUET': 71, 'BLACK THROATED WARBLER': 72, 'BLACK VENTED SHEARWATER': 73, 'BLACK VULTURE': 74, 'BLACK-CAPPED CHICKADEE': 75, 'BLACK-NECKED GREBE': 76, 'BLACK-THROATED SPARROW': 77, 'BLACKBURNIAM WARBLER': 78, 'BLONDE CRESTED WOODPECKER': 79, 'BLOOD PHEASANT': 80, 'BLUE DACNIS': 81, 'BLUE GRAY GNATCATCHER': 82, 'BLUE GROSBEAK': 83, 'BLUE HERON': 84, 'BLUE MALKOHA': 85, 'BLUE THROATED TOUCANET': 86, 'BOBOLINK': 87, 'BORNEAN LEAFBIRD': 88, 'BORNEAN PHEASANT': 89, 'BREWERS BLACKBIRD': 90, 'BROWN HEADED COWBIRD': 91, 'BROWN NOODY': 92, 'BUFFLEHEAD': 93, 'BULWERS PHEASANT': 94, 'BURCHELLS COURSER': 95, 'BUSH TURKEY': 96, 'CAATINGA CACHOLOTE': 97, 'CABOTS TRAGOPAN': 98, 'CALIFORNIA CONDOR': 99, 'CALIFORNIA GULL': 100, 'CAMPO FLICKER': 101, 'CANARY': 102, 'CANVASBACK': 103, 'CAPE GLOSSY STARLING': 104, 'CAPE LONGCLAW': 105, 'CAPE MAY WARBLER': 106, 'CAPE ROCK THRUSH': 107, 'CAPPED HERON': 108, 'CAPUCHINBIRD': 109, 'CASPIAN TERN': 110, 'CEDAR WAXWING': 111, 'CERULEAN WARBLER': 112, 'CHARA DE COLLAR': 113, 'CHATTERING LORY': 114, 'CHESTNUT WINGED CUCKOO': 115, 'CHINESE BAMBOO PARTRIDGE': 116, 'CHINESE POND HERON': 117, 'CHIPPING SPARROW': 118, 'CHUCAO TAPACULO': 119, 'CINNAMON FLYCATCHER': 120, 'CINNAMON TEAL': 121, 'CLARKS GREBE': 122, 'CLARKS NUTCRACKER': 123, 'COCK OF THE  ROCK': 124, 'COLLARED ARACARI': 125, 'COLLARED CRESCENTCHEST': 126, 'COMMON FIRECREST': 127, 'COMMON GRACKLE': 128, 'COMMON HOUSE MARTIN': 129, 'COMMON IORA': 130, 'COMMON LOON': 131, 'COMMON POORWILL': 132, 'COPPERY TAILED COUCAL': 133, 'CRAB PLOVER': 134, 'CRANE HAWK': 135, 'CREAM COLORED WOODPECKER': 136, 'CRESTED AUKLET': 137, 'CRESTED COUA': 138, 'CRESTED FIREBACK': 139, 'CRESTED KINGFISHER': 140, 'CRESTED OROPENDOLA': 141, 'CRESTED SERPENT EAGLE': 142, 'CRESTED SHRIKETIT': 143, 'CRIMSON CHAT': 144, 'CROW': 145, 'CUBAN TODY': 146, 'CUBAN TROGON': 147, 'DALMATIAN PELICAN': 148, 'DARJEELING WOODPECKER': 149, 'DARK EYED JUNCO': 150, 'DAURIAN REDSTART': 151, 'DEMOISELLE CRANE': 152, 'DOUBLE BARRED FINCH': 153, 'DOUBLE EYED FIG PARROT': 154, 'DOWNY WOODPECKER': 155, 'DUNLIN': 156, 'DUSKY LORY': 157, 'DUSKY ROBIN': 158, 'EARED PITA': 159, 'EASTERN BLUEBIRD': 160, 'EASTERN BLUEBONNET': 161, 'EASTERN MEADOWLARK': 162, 'EASTERN ROSELLA': 163, 'EASTERN TOWEE': 164, 'EASTERN WIP POOR WILL': 165, 'EASTERN YELLOW ROBIN': 166, 'ECUADORIAN HILLSTAR': 167, 'EGYP ...

# %%
y_train1=[]
for i in y_train:
    y_train1.append(label_map[i])

# %%
y_train1[:5]
# Out:
# [318, 13, 253, 72, 142]

# %%
y_test1=[]
for i in y_test:
    y_test1.append(label_map[i])

# %%
from tensorflow.keras.preprocessing.image import load_img,img_to_array
import numpy as np

def preprocess_image(img_path):
    img=load_img(img_path,target_size=(150,150))
    img_array=img_to_array(img)
    img_array=img_array/255.0
    return img_array

# %%
y=preprocess_image(img_path[0])
y.shape
# Out:
# (150, 150, 3)

# %%
import matplotlib.pyplot as plt
plt.imshow(y)

# %%
x_train_new=[]
for i in x_train:
    x_train_new.append(preprocess_image(i))

# %%
x_train_new=np.array(x_train_new)
x_train_new.shape
# Out:
# (1868, 150, 150, 3)

# %%
x_test_new=[]
for i in x_test:
    x_test_new.append(preprocess_image(i))

# %%
x_test_new=np.array(x_test_new)
x_test_new.shape
# Out:
# (468, 150, 150, 3)

# %%
plt.imshow(x_train_new[0])

# %% [markdown]
# Build a CNN model

# %%
# !pip install tensorflow
import tensorflow as tf
from tensorflow import keras
# Out:
# Requirement already satisfied: tensorflow in c:\users\dell\anaconda3\lib\site-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\dell\anaconda3\lib\site-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\dell\anaconda3\lib\site-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow) (1.73.0)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\dell\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in c:\users\dell\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\dell\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\dell\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (0.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\dell\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\dell\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\dell\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\dell\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\dell\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\dell\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\dell\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.0)

# %%
model=keras.Sequential([
    keras.layers.Conv2D(32,kernel_size=(3,3),activation='relu',input_shape=(150,150,3)), 
    keras.layers.MaxPooling2D((2,2)), 

    keras.layers.Conv2D(64,kernel_size=(3,3),activation='relu'), 
    keras.layers.MaxPooling2D((2,2)),

    keras.layers.Flatten(),
    keras.layers.Dense(64,activation='relu'),
    keras.layers.Dropout(0.4),
    keras.layers.Dense(len(categories),activation='softmax')
])

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(x_train_new,np.array(y_train1),epochs=10)
# Out:
# Epoch 1/10
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 8s 125ms/step - accuracy: 0.0032 - loss: 6.2073
# Epoch 2/10
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 8s 129ms/step - accuracy: 3.3366e-04 - loss: 6.1528
# Epoch 3/10
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 7s 126ms/step - accuracy: 0.0055 - loss: 6.1000
# Epoch 4/10
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.0171 - loss: 5.9065
# Epoch 5/10
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 8s 130ms/step - accuracy: 0.0904 - loss: 5.0900
# Epoch 6/10
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 8s 127ms/step - accuracy: 0.2547 - loss: 3.7477
# Epoch 7/10
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 8s 127ms/step - accuracy: 0.4632 - loss: 2.4438
# Epoch 8/10
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 8s 127ms/step - accuracy: 0.6138 - loss: 1.6930
# Epoch 9/10
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.6927 - loss: 1.2729
# Epoch 10/10
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 8s 129ms/step - accuracy: 0.7553 - loss: 1.0343

# %%
model.evaluate(x_test_new,np.array(y_test1))
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.0285 - loss: 9.3882
# [9.331480979919434, 0.03205128386616707]

# %% [markdown]
# Prediction with single image

# %%
img_path=r"C:\Users\DELL\Downloads\birds_species\CAMPO FLICKER\1.jpg"
y_pred=preprocess_image(img_path)
y_pred
# Out:
# array([[[0.12941177, 0.17254902, 0.11764706],
#         [0.13725491, 0.18039216, 0.1254902 ],
#         [0.14117648, 0.18431373, 0.12941177],
#         ...,
#         [0.32941177, 0.3529412 , 0.20392157],
#         [0.32156864, 0.34901962, 0.1882353 ],
#         [0.32156864, 0.34901962, 0.18431373]],
#
#        [[0.14901961, 0.18039216, 0.12941177],
#         [0.13333334, 0.16470589, 0.11372549],
#         [0.14117648, 0.17254902, 0.12156863],
#         ...,
#         [0.33333334, 0.3647059 , 0.21176471],
#         [0.32156864, 0.3529412 , 0.2       ],
#         [0.3372549 , 0.36862746, 0.21568628]],
#
#        [[0.14901961, 0.18039216, 0.12941177],
#         [0.12941177, 0.16078432, 0.10980392],
#         [0.13725491, 0.16862746, 0.11764706],
#         ...,
#         [0.3254902 , 0.35686275, 0.20392157],
#         [0.3137255 , 0.34509805, 0.2       ],
#         [0.32941177, 0.35686275, 0.22352941]],
#
#        ...,
#
#        [[0.18431373, 0.2       , 0.13333334],
#         [0.16470589, 0.18039216, 0.11372549],
#         [0.16470589, 0.18039216, 0.11372549],
#         ...,
#         [0.36862746, 0.32156864, 0.21960784],
#         [0.34117648, 0.29411766, 0.2       ],
#         [0.3647059 , 0.31764707, 0.23137255]],
#
#        [[0.1764706 , 0.19215687, 0.1254902 ],
#         [0.17254902, 0.1882353 , 0.12156863],
#         [0.1764706 , 0.19215687, 0.1254902 ],
#         ...,
#         [0.37254903, 0.3137255 , 0.23137255],
#         [0.3529412 , 0.29411766, 0.21176471],
#         [0.35686275, 0.30588236, 0.23137255]],
#
#        [[0.16862746, 0.18431373, 0.11764706],
#         [0.18039216, 0.19607843, 0.12941177],
#         [0.18039216, 0.19607843, 0.12941177],
#         ...,
#         [0.34509805, 0.3254902 , 0.2       ],
#         [0.34117648, 0.32156864, 0.20392157],
#         [0.3372549 , 0.31764707, 0.2       ]]], dtype=float32)

# %%
y_prediction=model.predict(np.array([y_pred]))
y_prediction
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# array([[1.77027262e-03, 1.27096928e-03, 9.48666874e-03, 6.44079875e-04,
#         6.49159629e-05, 2.12555620e-04, 4.96646215e-04, 7.29956431e-04,
#         1.74622819e-05, 2.20373413e-03, 5.19750873e-03, 3.80036683e-04,
#         1.32618254e-04, 2.04567667e-04, 1.20702360e-04, 5.97704900e-04,
#         9.21002298e-04, 7.09912216e-04, 1.60121097e-04, 1.49278101e-04,
#         6.37881807e-04, 8.46856914e-04, 6.15277607e-03, 5.36569348e-03,
#         3.76250362e-03, 8.74051941e-04, 2.10791477e-03, 1.15483277e-03,
#         2.77146231e-04, 9.81592853e-03, 2.91995937e-03, 4.93204407e-03,
#         1.06971234e-03, 1.50635606e-03, 6.13020093e-04, 4.54629119e-03,
#         1.51841814e-04, 1.69407780e-04, 9.47355875e-04, 2.26542237e-03,
#         6.04797853e-03, 1.14833507e-04, 6.56645803e-04, 1.29352717e-04,
#         2.05037199e-04, 7.96507447e-06, 2.89363135e-03, 6.06828695e-03,
#         4.77282703e-03, 1.42987375e-03, 1.09302171e-03, 6.87874097e-04,
#         1.42541685e-04, 4.33749659e-03, 1.32799498e-03, 8.94490688e-04,
#         7.77126916e-05, 2.66224466e-04, 4.02485457e-05, 8.15190142e-04,
#         1.94704524e-04, 8.18761982e-05, 1.13369249e-04, 6.48725763e-05,
#         3.20798979e-04, 3.49760358e-03, 8.39697750e-05, 8.08170822e-04,
#         6.17184956e-03, 1.21188292e-03, 8.79409316e-04, 1.08557439e-03,
#         6.25892251e-04, 2.49582401e-04, 4.42592973e-05, 2.77963205e-04,
#         9.05300491e-04, 1.54359220e-03, 5.89239411e-04, 1.12745706e-02,
#         2.26212130e-03, 8.02578143e-05, 6.49229332e-04, 9.95135633e-04,
#         5.57866530e-04, 8.13621213e-04, 8.32614303e-03, 8.31971003e-04,
#         7.75765860e-03, 4.63687320e-04, 3.02866707e-03, 3.18275988e-02,
#         6.39036880e-04, 1.44303514e-04, 4.18286631e-03, 2.43864080e-04,
#         1.26853469e-04, 5.93599572e-04, 4.45551181e-04, 3.77618853e-04,
#         1.57467366e-04, 8.33348781e-02, 9.69576242e-04, 1.76938440e-04,
#         2.22722790e-03, 5.33589337e-04, 2.79746455e-04, 2.51574180e-04,
#         1.03386783e-03, 1.18949066e-03, 8.64269387e-04, 6.59097335e-04,
#         1.50170806e-03, 2.27061682e-04, 4.14743042e-03, 7.37255579e-03,
#         1.20418821e-03, 3.57633835e-04, 1.21984659e-02, 2.48164614e-03,
#         6.01980428e-04, 5.52380865e-04, 1.04312086e-03, 2.21538171e-03,
#         2.32203020e-04, 1.01391354e-03, 7.11390749e-04, 4.53169085e-03,
#         1.07123242e-05, 7.29010644e-05, 5.32491074e-04, 1.74863126e-05,
#         1.82374474e-03, 3.47291585e-03, 1.02731421e-04, 1.00556668e-03,
#         1.44812075e-04, 1.06153509e-03, 9.23675398e-05, 2.10449332e-04,
#         2.93491944e-03, 2.54722638e-03, 4.45828913e-03, 1.93794142e-03,
#         8.47990668e-05, 1.26167154e-03, 1.90783909e-03, 6.04215194e-04,
#         8.72879114e-04, 4.67998767e-03, 6.72827242e-03, 6.23323256e-03,
#         3.56325554e-03, 2.55016494e-03, 1.33457477e-03, 2.69923601e-02,
#         2.14898057e-04, 1.37530529e-04, 3.93790426e-04, 3.99391400e-04,
#         1.52398169e-03, 6.15541416e-04, 6.20656821e-04, 6.45917899e-04,
#         1.07899716e-04, 7.14960392e-04, 3.50605417e-03, 1.19634969e-04,
#         3.92006885e-04, 8.60881875e-04, 8.17022636e-04, 1.88367546e-03,
#         4.05531982e-03, 4.20364877e-03, 1.73537375e-03, 1.07272959e-03,
#         5.15103980e-04, 1.27820317e-02, 1.15324347e-03, 5.89237723e-04,
#         3.80059500e-04, 1.04817678e-03, 5.88928722e-03, 4.42725635e-04,
#         4.84606531e-03, 8.03280389e-04, 8.56680708e-05, 2.82516936e-03,
#         5.58112632e-04, 5.26956341e-04, 3.34728253e-03, 2.31567989e-04,
#         1.17771933e-02, 1.03394967e-03, 1.20765623e-03, 2.50021438e-03,
#         4.19316522e-04, 8.67574709e-04, 1.33689004e-03, 2.29456834e-03,
#         2.72675185e-04, 3.06285190e-04, 2.34497269e-03, 2.72010584e-05,
#         6.72760536e-04, 1.78236340e-04, 7.49107741e-04, 8.65451220e-05,
#         4.37559560e-04, 1.32241205e-03, 4.43980942e-04, 4.58545750e-04,
#         1.13651389e-02, 2.47606682e-03, 6.34725075e-05, 1.34513946e-03,
#         2.94078072e-03, 3.16975242e-03, 3.26438225e-03, 1.19030254e-03,
#         7.45443720e-03, 4.95398825e-04, 4.54793917e-03, 9.94831091e-04,
#         2.83724774e-04, 2.08338583e-03, 2.27891118e-03, 4.67638863e-04,
#         1.18998624e-02, 6.88637083e-04, 2.19986006e-03, 3.37790791e-03,
#         5.40850824e-03, 1.16211707e-02, 1.67583814e-04, 4.25330782e-03,
#         1.04326056e-02, 1.47083413e-03, 1.12805469e-03, 6.08225702e-04,
#         2.88875913e-03, 5.36660198e-03, 3.28690861e-04, 7.54068169e-05,
#         4.10137378e-04, 1.12095440e-04, 3.24042281e-04, 7.86494184e-03,
#         6.61426689e-03, 1.87934027e-03, 2.51719848e-05, 1.25745544e-04,
#         6.34998141e-05, 2.37489454e-04, 4.93977126e-03, 2.11440012e-04,
#         1.76725734e-03, 2.15174819e-04, 1.00716701e-04, 7.22174649e-04,
#         2.55249836e-03, 1.91196101e-03, 1.22613655e-02, 2.54287082e-03,
#         1.47984596e-03, 5.97193837e-04, 1.10153086e-03, 1.09749621e-04,
#         9.80188837e-04, 1.52833789e-04, 5.27964949e-05, 4.31365101e-03,
#         3.34457320e-04, 1.51110929e-03, 1.04491060e-04, 2.10780156e-04,
#         2.35593063e-03, 5.33601735e-03, 8.29881756e-04, 7.64615426e-04,
#         4.61324671e-04, 8.37348343e-04, 9.64166829e-04, 1.55082089e-03,
#         1.95963163e-04, 1.29158012e-04, 5.04273630e-04, 9.48342402e-03,
#         1.52444746e-03, 3.44841217e-04, 4.20643861e-04, 1.88205217e-03,
#         1.19904755e-04, 1.70319027e-03, 3.69731162e-04, 1.71667183e-04,
#         2.35400139e-03, 3.53104156e-03, 1.13885221e-03, 2.95973010e-03,
#         5.38711157e-03, 7.30428947e-05, 9.67729744e-03, 4.27862542e-04,
#         8.42915149e-04, 9.93415015e-05, 9.54548828e-04, 1.37485168e-03,
#         4.44263889e-04, 2.57611577e-03, 1.32374710e-03, 7.70083105e-04,
#         5.71839744e-03, 8.37792875e-04, 9.32841853e-04, 1.02644510e-04,
#         3.78268585e-03, 1.44678459e-03, 1.05076004e-04, 3.88889282e-04,
#         6.48800109e-04, 1.27889129e-04, 2.10852502e-03, 6.80106168e-04,
#         1.32288566e-04, 2.81942157e-05, 3.63255327e-04, 3.09342355e-03,
#         3.00818036e-04, 4.25818231e-04, 6.19266508e-03, 1.38224670e-04,
#         8.24485105e-05, 1.10588349e-04, 5.06415323e-04, 1.06593734e-03,
#         2.13522976e-03, 1.36254341e-04, 2.47113785e-04, 1.65619480e-03,
#         1.46478837e-04, 1.51821319e-03, 3.83899023e-04, 1.44783279e-03,
#         1.32566481e-03, 5.59861190e-04, 2.08468153e-03, 2.20824368e-05,
#         4.59238727e-05, 1.32642803e-04, 4.60378389e-04, 1.44952865e-04,
#         1.09638677e-04, 7.89506419e-04, 1.35896308e-03, 6.05762354e-04,
#         3.85747233e-04, 5.10246318e-04, 4.39147791e-03, 5.25304524e-04,
#         9.70944297e-04, 2.85215676e-04, 7.20493030e-04, 1.52427674e-04,
#         2.01524381e-04, 4.58994415e-03, 3.14906792e-04, 5.75810380e-04,
#         2.15423736e-03, 6.77617849e-04, 5.68488496e-04, 5.60291403e-04,
#         4.50622028e-04, 1.95208320e-03, 5.79053676e-03, 4.24248725e-03,
#         1.12731490e-04, 3.04807822e-04, 5.36209112e-03, 4.93215281e-04,
#         6.92371832e-05, 5.03426511e-03, 1.59776174e-02, 6.08505215e-03,
#         1.34680490e-03, 3.97687918e-03, 1.53785525e-03, 3.87198525e-03,
#         3.35484720e-03, 4.14637470e-04, 2.00320384e-03, 5.50481454e-05,
#         3.82886035e-04, 3.10019404e-03, 2.14753425e-04, 3.20464908e-03,
#         1.68779457e-03, 6.68451714e-04, 3.84723680e-04, 2.81269400e-04,
#         3.68620531e-04, 1.02819737e-04, 6.56371529e-04, 3.93221388e-03,
#         6.54972950e-03, 8.58336047e-04, 4.56876558e-04, 2.06220872e-03,
#         7.53511777e-05, 5.48710887e-05, 2.08434169e-04, 6.33748248e-04,
#         1.22996513e-03, 2.91987031e-04, 2.06453772e-03, 1.49168377e-03,
#         6.26472989e-04, 1.44179573e-03, 1.09742439e-04, 9.64644551e-03,
#         4.13534930e-03, 5.43240341e-04, 1.60367438e-03, 5.29947865e-04,
#         1.05221802e-03, 1.87594688e-03, 4.43916622e-04, 1.64941314e-03,
#         2.82556401e-03, 5.95376652e-04, 5.26878168e-04, 4.76694899e-04,
#         6.86363317e-04, 5.59069740e-05, 2.15673528e-04, 3.73222807e-04,
#         1.02208462e-03, 9.37979639e-05, 5.49462298e-03, 8.19100969e-05,
#         3.54551477e-04, 1.23555481e-03, 2.41774178e-04, 7.53354141e-03,
#         3.19403422e-04, 2.42339121e-03, 5.05258795e-04, 2.61073373e-03,
#         1.39510271e-03, 2.19880510e-03, 3.04332492e-03, 1.63172183e-04,
#         2.04955880e-03, 1.44733314e-03, 8.83425178e-04, 3.11721902e-04,
#         9.11164563e-03, 1.64939824e-03, 9.12316144e-03, 1.40871023e-04,
#         4.47165640e-03, 2.34139734e-03, 1.19643184e-04, 1.25875045e-03,
#         4.15023998e-04, 2.63421144e-03, 9.51169641e-05, 6.44562882e-04,
#         1.76080584e-03, 1.39729595e-02, 7.70941330e-03]], dtype=float32)

# %%
plt.imshow(y_pred)
plt.title(categories[np.argmax(y_prediction)])
# Out:
# Text(0.5, 1.0, 'CAMPO FLICKER')
